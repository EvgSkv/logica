# %%
# !echo 'Welcome to simple Souffle graph benchmarking.'
# !echo 'Behold the power of The Machine:'
# !echo "CPUs: $(nproc) / RAM: $(free -h | awk '/^Mem:/ {print $2}')"
# Out:
# Welcome to simple Souffle graph benchmarking.
# Behold the power of The Machine:
# CPUs: 32 / RAM: 125Gi

# %%
from IPython.core.magic import register_cell_magic
from IPython import get_ipython
import time
from logica.common import sqlite3_logica
import pandas

timing = {}

reports = []

@register_cell_magic
def loop(line, cell):
    global timing
    local_timing = {}
    ip = get_ipython()
    # Evaluate the line to get the list (e.g., "my_files")
    problem_name, iterator = ip.ev(line) 
    
    for item in iterator:
        # Inject 'item' into global namespace so the inner magic sees it
        ip.user_ns['loop_parameter'] = item 
        # Run the content as a new cell execution
        start_time = time.perf_counter()
        ip.run_cell(cell.replace('{loop_parameter}', item))
        end_time = time.perf_counter()
        elapsed = end_time - start_time
        timing[item] = elapsed
        local_timing[item] = elapsed
    report = (' === Timing for %s ===\n' % problem_name) + (
        sqlite3_logica.DataframeAsArtisticTable(pandas.DataFrame({'problem': list(local_timing.keys()),
                                                                  'time': list(local_timing.values())})))
    reports.append(report)
    print(report)

# %%
test_items = ['a', 'b', 'c']

# %%
# %%loop ("Test Problem", test_items)
# print("{loop_parameter}")
# Out:
# a
# b
# c
#  === Timing for Test Problem ===
# +---------+------------------------+
# | problem | time                   |
# +---------+------------------------+
# | a       | 0.00022014000001036038 |
# | b       | 0.00017433999994409533 |
# | c       | 0.00016089000007468712 |
# +---------+------------------------+

# %%
print(reports[0])
# Out:
#  === Timing for Test Problem ===
# +---------+------------------------+
# | problem | time                   |
# +---------+------------------------+
# | a       | 0.00022014000001036038 |
# | b       | 0.00017433999994409533 |
# | c       | 0.00016089000007468712 |
# +---------+------------------------+

# %%
from logica import colab_logica
# Out:
# Could not import google.cloud.bigquery.
# Could not import google.cloud.auth.
# Could not import google.colab.widgets.

# %%
# %%logica G,S
#
# @AttachDatabase("db", "graphs.db");
#
# N() = 100;
# D() = 10;
#
# GStep1(a, b, i:) distinct :-
#   a = NaturalHash("a-" ++ ToString(i)) % N(),
#   b = NaturalHash("b-" ++ ToString(i)) % N(),
#   a != b,
#   i in Range(ToInt64(N() * D() * 1.1));
#
# I() = l[N() * D()] :-
#   l = Array{ i -> i :- GStep1(i:) };
#
# G(a, b) :-
#   GStep1(a, b, i:),
#   i < I();
#
#
# @Ground(G5c, "db.G5c", copy_to_file: "graph_bench/g5c.csv");
# G5c := G(N: 500);
# @Ground(G6c, "db.G6c", copy_to_file: "graph_bench/g6c.csv");
# G6c := G(N: 600);
# @Ground(G7c, "db.G7c", copy_to_file: "graph_bench/g7c.csv");
# G7c := G(N: 700);
#
# @Ground(G1k, "db.G1k", copy_to_file: "graph_bench/g1k.csv");
# G1k := G(N: 1000);
# @Ground(G2k, "db.G2k", copy_to_file: "graph_bench/g2k.csv");
# G2k := G(N: 2000);
# @Ground(G3k, "db.G3k", copy_to_file: "graph_bench/g3k.csv");
# G3k := G(N: 3000);
# @Ground(G4k, "db.G4k", copy_to_file: "graph_bench/g4k.csv");
# G4k := G(N: 4000);
# @Ground(G5k, "db.G5k", copy_to_file: "graph_bench/g5k.csv");
# G5k := G(N: 5000);
#
# S() += 1 :- G5c() | G6c() | G7c() | G1k() | G2k() | G3k() | G4k() | G5k();
# Out:
# Query is stored at G_sql variable.
# The following table is stored at G variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>95</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>80</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>32</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>29</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>73</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>61</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>46</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>80</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>10</td>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>85</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>76</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>75</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>5</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>47</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>3</td>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>86</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>11</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>71</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>9</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>94</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>60</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>74</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>70</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>37</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>78</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>0</td>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>81</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>72</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>57</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>970</th>
#       <td>36</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>971</th>
#       <td>57</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>972</th>
#       <td>85</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>973</th>
#       <td>92</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>974</th>
#       <td>81</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>975</th>
#       <td>71</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>976</th>
#       <td>40</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>977</th>
#       <td>18</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>978</th>
#       <td>15</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>979</th>
#       <td>24</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>980</th>
#       <td>53</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>981</th>
#       <td>51</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>982</th>
#       <td>98</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>983</th>
#       <td>33</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>984</th>
#       <td>20</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>985</th>
#       <td>87</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>986</th>
#       <td>33</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>987</th>
#       <td>22</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>988</th>
#       <td>63</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>989</th>
#       <td>0</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>990</th>
#       <td>21</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <th>991</th>
#       <td>56</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>992</th>
#       <td>22</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>993</th>
#       <td>68</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>994</th>
#       <td>46</td>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>995</th>
#       <td>95</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>996</th>
#       <td>5</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>997</th>
#       <td>74</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>998</th>
#       <td>74</td>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>999</th>
#       <td>26</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at S_sql variable.
# The following table is stored at S variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>168000</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥        ▚  G4k (46 ms)
# ║╥       ▚  G7c (14 ms)
# ║║╥      ▚  G5c (11 ms)
# ║║║╥     ▚  G5k (53 ms)
# ║║║║     ▚  G (4 ms)
# ║║║║╥    ▚  G6c (12 ms)
# ║║║║║╥   ▚  G1k (16 ms)
# ║║║║║║╥  ▚  G2k (25 ms)
# ║║║║║║║╥ ▚  G3k (36 ms)
# ╨╨╨╨╨╨╨╨ ▚  S (1 ms)
# [     Execution complete.      ]                              </pre></div>

# %%
graphs = ['G1k', 'G2k', 'G3k', 'G4k', 'G5k']

# %%
# %%logica Tree, NumNodes
#
# @AttachDatabase("db", "graphs.db");
#
# Depth() = 5;
# DegreeRange(1, 5);
#
# InnerTree(x, y) :-
#     (x = "0" | InnerTree(something, x)),
#     Length(x) < Depth(),
#     DegreeRange(d1, d2),
#     d = NaturalHash("d-" ++ x) % (d2 - d1) + d1,
#     i in Range(d),
#     y = x ++ ToString(i);
#
# # Creating a non-recursive face, so we can customly ground it.
# Tree(x, y) :- InnerTree(x, y);
#
# @Ground(Tree5, "db.Tree5", copy_to_file: "graph_bench/tree5.csv");
# Tree5 := Tree(Depth: 5);
# @Ground(Tree6, "db.Tree6", copy_to_file: "graph_bench/tree6.csv");
# Tree6 := Tree(Depth: 6);
# @Ground(Tree7, "db.Tree7", copy_to_file: "graph_bench/tree7.csv");
# Tree7 := Tree(Depth: 7);
# @Ground(Tree8, "db.Tree8", copy_to_file: "graph_bench/tree8.csv");
# Tree8 := Tree(Depth: 8);
# @Ground(Tree9, "db.Tree9", copy_to_file: "graph_bench/tree9.csv");
# Tree9 := Tree(Depth: 9);
# @Ground(Tree10, "db.Tree10", copy_to_file: "graph_bench/tree10.csv");
# Tree10 := Tree(Depth: 10);
# @Ground(Tree11, "db.Tree11", copy_to_file: "graph_bench/tree11.csv");
# Tree11 := Tree(Depth: 11);
# @Ground(Tree12, "db.Tree12", copy_to_file: "graph_bench/tree12.csv");
# Tree12 := Tree(Depth: 12);
#
# NumNodes(tree5: Sum{ 1 :- Tree5()},
#          tree6: Sum{ 1 :- Tree6()},
#          tree7: Sum{ 1 :- Tree7()},
#          tree8: Sum{ 1 :- Tree8()},
#          tree9: Sum{ 1 :- Tree9()},
#          tree10: Sum{ 1 :- Tree10()},
#          tree11: Sum{ 1 :- Tree11()},
#          tree12: Sum{ 1 :- Tree12()}
#         );
# Out:
# Query is stored at Tree_sql variable.
# The following table is stored at Tree variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>01</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0110</td>
#       <td>01100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0110</td>
#       <td>01101</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0110</td>
#       <td>01102</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>011</td>
#       <td>0110</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>011</td>
#       <td>0111</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>00</td>
#       <td>000</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0111</td>
#       <td>01110</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0111</td>
#       <td>01111</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0111</td>
#       <td>01112</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0111</td>
#       <td>01113</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>010</td>
#       <td>0100</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>01</td>
#       <td>010</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>01</td>
#       <td>011</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0001</td>
#       <td>00010</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0001</td>
#       <td>00011</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>0001</td>
#       <td>00012</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>000</td>
#       <td>0000</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>000</td>
#       <td>0001</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>0000</td>
#       <td>00000</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>0100</td>
#       <td>01000</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>0100</td>
#       <td>01001</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>0100</td>
#       <td>01002</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>0100</td>
#       <td>01003</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at NumNodes_sql variable.
# The following table is stored at NumNodes variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tree5</th>
#       <th>tree6</th>
#       <th>tree7</th>
#       <th>tree8</th>
#       <th>tree9</th>
#       <th>tree10</th>
#       <th>tree11</th>
#       <th>tree12</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25</td>
#       <td>68</td>
#       <td>180</td>
#       <td>471</td>
#       <td>1205</td>
#       <td>3080</td>
#       <td>7781</td>
#       <td>19504</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥          ▚  InnerTree_ifr0_f7 (38 ms)
# ║╥         ▚  InnerTree_ifr0_f11 (0 ms)
# ║║╥        ▚  InnerTree_ifr0_f13 (0 ms)
# ║║║╥       ▚  InnerTree_ifr0_f8 (0 ms)
# ║║║║╥      ▚  InnerTree_ifr0_f10 (0 ms)
# ║║║║║╥     ▚  InnerTree_ifr0_f9 (0 ms)
# ║║╨║║║╥    ▚  InnerTree_ifr1_f13 (60 ms)
# ║║╥║║║║    ▚  InnerTree_ifr0_f12 (0 ms)
# ║║║║║║╨╥   ▚  InnerTree_ifr2_f13 (3 ms) 15 / 15
# ║║║║║║╥║   ▚  InnerTree_ifr0 (0 ms)
# ║║║║║║║║╥  ▚  InnerTree_ifr0_f14 (0 ms)
# ║║║║║║║╨║╥ ▚  InnerTree_ifr3_f13 (3 ms) 15 / 15
# ║║╨║║║║╥║║ ▚  InnerTree_ifr1_f12 (2 ms)
# ║║╥║║║║╨║║ ▚  InnerTree_ifr2_f12 (2 ms) 15 / 15
# ║╨║║║║║╥║║ ▚  InnerTree_ifr1_f11 (1 ms)
# ║╥║║║║║║╨║ ▚  InnerTree_ifr1_f14 (1 ms)
# ╨║║║║║║║╥║ ▚  InnerTree_ifr1_f7 (1 ms)
# ╥║║║║╨║║║║ ▚  InnerTree_ifr1_f9 (1 ms)
# ║║║║║╥║╨║║ ▚  InnerTree_ifr2_f11 (1 ms) 15 / 15
# ║║║╨║║║╥║║ ▚  InnerTree_ifr1_f8 (1 ms)
# ║╨║╥║║║║║║ ▚  InnerTree_ifr2_f14 (4 ms) 15 / 15
# ║╥║║╨║║║║║ ▚  InnerTree_ifr1_f10 (1 ms)
# ╨║║║╥║║║║║ ▚  InnerTree_ifr2_f9 (56 ms) 15 / 15
# ╥║╨║║║║║║║ ▚  InnerTree_ifr3_f12 (2 ms) 15 / 15
# ║║╥║╨║║║║║ ▚  InnerTree_ifr3_f9 (57 ms) 15 / 15
# ║║║║╥╨║║║║ ▚  InnerTree_ifr3_f11 (2 ms) 15 / 15
# ║║║║║╥╨║║║ ▚  InnerTree_ifr1 (1 ms)
# ║║║║║╨╥║║║ ▚  InnerTree_ifr2 (2 ms) 15 / 15
# ║║║║║╥║║╨║ ▚  InnerTree_ifr2_f7 (10 ms) 15 / 15
# ║║║║║║║╨╥║ ▚  InnerTree_ifr2_f8 (23 ms) 15 / 15
# ║║║║║║║╥╨║ ▚  InnerTree_ifr3_f8 (25 ms) 15 / 15
# ║║╨║║║║║╥║ ▚  InnerTree_f9 (54 ms)
# ║║╥║║╨║║║║ ▚  InnerTree_ifr3_f7 (10 ms) 15 / 15
# ║║║║║╥║║║╨ ▚  InnerTree_f13 (3 ms)
# ║║╨║║║║║║╥ ▚  InnerTree_f7 (10 ms)
# ║║╥║║║╨║║║ ▚  InnerTree_ifr3 (2 ms) 15 / 15
# ║║║║╨║╥║║║ ▚  InnerTree_f11 (1 ms)
# ║║║╨╥║║║║║ ▚  InnerTree_ifr3_f14 (5 ms) 15 / 15
# ║║║╥║║║║╨║ ▚  Tree12 (16 ms)
# ║╨║║║║║║╥║ ▚  InnerTree_ifr2_f10 (2 ms) 15 / 15
# ║╥║║║╨║║║║ ▚  Tree8 (5 ms)
# ╨║║║║╥║║║║ ▚  InnerTree_f12 (2 ms)
# ╥║║║║║║║╨║ ▚  InnerTree_ifr3_f10 (2 ms) 15 / 15
# ║║║║║║║║╥╨ ▚  Tree10 (6 ms)
# ║║║║║║║╨║╥ ▚  InnerTree_f8 (22 ms)
# ║║╨║║║║╥║║ ▚  InnerTree (2 ms)
# ║║╥║║║╨║║║ ▚  Tree6 (4 ms)
# ╨║║║║║╥║║║ ▚  InnerTree_f10 (1 ms)
#  ║║║║║║╨║║ ▚  Tree (0 ms)
# ╥║║║╨║║ ║║ ▚  InnerTree_f14 (5 ms)
# ║║║║╥║║ ║╨ ▚  Tree11 (9 ms)
# ║║║║║║╨╥║  ▚  Tree5 (4 ms)
# ║║║║║╨╥║║  ▚  Tree7 (4 ms)
# ╨║║║║╥║║║  ▚  Tree9 (5 ms)
#  ╨╨╨╨╨╨╨╨  ▚  NumNodes (15 ms)
# [     Execution complete.      ]                              </pre></div>

# %%
trees = ['Tree7', 'Tree8', 'Tree9', 'Tree10', 'Tree11', 'Tree12']

# %%
# %%loop ("Transitive Closure", graphs)
# %%logica TC
#
# @AttachDatabase("db", "graphs.db");
#
# G(a, b) :- db.{loop_parameter}(a, b);
#
# @Recursive(TC, ∞, stop: Done);
# TC(a, b) distinct :- G(a, b);
# TC(a, c) distinct :- TC(a, b), G(b, c);
#
# PrevTC(a, b) :- TC(a, b);
#
# Done() :- TC(a, b) => PrevTC(a, b);
# Out:
# Query is stored at TC_sql variable.
# The following table is stored at TC variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>931</td>
#       <td>419</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>243</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>542</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>95</td>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>325</td>
#       <td>567</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>764</td>
#       <td>632</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>984</td>
#       <td>756</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>683</td>
#       <td>783</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>398</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>747</td>
#       <td>944</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>260</td>
#       <td>618</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>350</td>
#       <td>317</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>437</td>
#       <td>270</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>568</td>
#       <td>935</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>708</td>
#       <td>132</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>78</td>
#       <td>885</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>236</td>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>693</td>
#       <td>820</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>25</td>
#       <td>193</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>675</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>851</td>
#       <td>586</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>693</td>
#       <td>123</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>161</td>
#       <td>213</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>429</td>
#       <td>411</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>405</td>
#       <td>955</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>423</td>
#       <td>285</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>896</td>
#       <td>766</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>47</td>
#       <td>575</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>25</td>
#       <td>649</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>13</td>
#       <td>576</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>998970</th>
#       <td>736</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998971</th>
#       <td>309</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998972</th>
#       <td>749</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998973</th>
#       <td>890</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998974</th>
#       <td>11</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998975</th>
#       <td>331</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998976</th>
#       <td>91</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998977</th>
#       <td>248</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998978</th>
#       <td>286</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998979</th>
#       <td>386</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998980</th>
#       <td>777</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998981</th>
#       <td>834</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998982</th>
#       <td>291</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998983</th>
#       <td>849</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998984</th>
#       <td>707</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998985</th>
#       <td>198</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998986</th>
#       <td>217</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998987</th>
#       <td>342</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998988</th>
#       <td>773</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998989</th>
#       <td>168</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998990</th>
#       <td>949</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998991</th>
#       <td>839</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998992</th>
#       <td>403</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998993</th>
#       <td>577</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998994</th>
#       <td>357</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998995</th>
#       <td>678</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998996</th>
#       <td>798</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998997</th>
#       <td>502</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998998</th>
#       <td>546</td>
#       <td>943</td>
#     </tr>
#     <tr>
#       <th>998999</th>
#       <td>183</td>
#       <td>943</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G1k (input data)
# ╨╥    ▚  TC_ifr0 (2 ms)
# ╥╨    ▚  TC_ifr1 (8 ms)
# ╨╥╥   ▚  TC_ifr2 (62 ms)
# ╥╨║   ▚  PrevTC_ifr3 (2 ms)
# ║╥╨╥╥ ▚  TC_ifr3 (110 ms)
# ╨╨ ║║ ▚  Done_ifr4 (41 ms) 3 / ∞ / stop.
# ╥╥╥╨║ ▚  TC_ifr4 (110 ms) 3 / ∞ / stop.
# ║║║╥╨ ▚  PrevTC_ifr4 (4 ms) 3 / ∞ / stop.
# ╨║║║  ▚  PrevTC_ifr5 (4 ms) 3 / ∞ / stop.
# ╥╨║║  ▚  TC_ifr5 (124 ms) 3 / ∞ / stop.
# ║ ╨╨  ▚  Done_ifr5 (66 ms) 2 / ∞ / stop.
# ╨     ▚  TC (120 ms)
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at TC_sql variable.
# The following table is stored at TC variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>571</td>
#       <td>1979</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>124</td>
#       <td>1595</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>999</td>
#       <td>1893</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>180</td>
#       <td>1194</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1744</td>
#       <td>1179</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1234</td>
#       <td>758</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1627</td>
#       <td>489</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1990</td>
#       <td>239</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>964</td>
#       <td>894</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1089</td>
#       <td>885</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1460</td>
#       <td>456</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>352</td>
#       <td>1535</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1542</td>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1780</td>
#       <td>925</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1347</td>
#       <td>328</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1455</td>
#       <td>1506</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1769</td>
#       <td>755</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>658</td>
#       <td>551</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>589</td>
#       <td>906</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>33</td>
#       <td>802</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>69</td>
#       <td>1531</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1336</td>
#       <td>586</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>987</td>
#       <td>637</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>6</td>
#       <td>1663</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>963</td>
#       <td>727</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1003</td>
#       <td>1562</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1828</td>
#       <td>232</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1985</td>
#       <td>1829</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1147</td>
#       <td>1102</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>492</td>
#       <td>1023</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>3997970</th>
#       <td>1110</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997971</th>
#       <td>1287</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997972</th>
#       <td>497</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997973</th>
#       <td>932</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997974</th>
#       <td>620</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997975</th>
#       <td>1941</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997976</th>
#       <td>1768</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997977</th>
#       <td>638</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997978</th>
#       <td>1455</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997979</th>
#       <td>1371</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997980</th>
#       <td>123</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997981</th>
#       <td>1149</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997982</th>
#       <td>1597</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997983</th>
#       <td>1518</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997984</th>
#       <td>905</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997985</th>
#       <td>1288</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997986</th>
#       <td>669</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997987</th>
#       <td>697</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997988</th>
#       <td>1327</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997989</th>
#       <td>1143</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997990</th>
#       <td>60</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997991</th>
#       <td>1226</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997992</th>
#       <td>1626</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997993</th>
#       <td>1623</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997994</th>
#       <td>1858</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997995</th>
#       <td>1963</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997996</th>
#       <td>1329</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997997</th>
#       <td>1641</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997998</th>
#       <td>318</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3997999</th>
#       <td>650</td>
#       <td>1346</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G2k (input data)
# ╨╥    ▚  TC_ifr0 (2 ms)
# ╥╨    ▚  TC_ifr1 (15 ms)
# ╨╥╥   ▚  TC_ifr2 (65 ms)
# ╥╨║   ▚  PrevTC_ifr3 (5 ms)
# ║╥╨╥╥ ▚  TC_ifr3 (230 ms)
# ╨╨ ║║ ▚  Done_ifr4 (90 ms) 3 / ∞ / stop.
# ╥╥╥╨║ ▚  TC_ifr4 (287 ms) 3 / ∞ / stop.
# ║║║╥╨ ▚  PrevTC_ifr4 (8 ms) 3 / ∞ / stop.
# ╨║║║  ▚  PrevTC_ifr5 (9 ms) 3 / ∞ / stop.
# ╥╨║║  ▚  TC_ifr5 (300 ms) 3 / ∞ / stop.
# ║ ╨╨  ▚  Done_ifr5 (95 ms) 2 / ∞ / stop.
# ╨     ▚  TC (329 ms)
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at TC_sql variable.
# The following table is stored at TC variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>826</td>
#       <td>1104</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1019</td>
#       <td>2746</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>29</td>
#       <td>1466</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>626</td>
#       <td>1711</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2589</td>
#       <td>2751</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0</td>
#       <td>1484</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2424</td>
#       <td>1253</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>582</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2764</td>
#       <td>1192</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>784</td>
#       <td>861</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>414</td>
#       <td>1196</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1434</td>
#       <td>558</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1665</td>
#       <td>1435</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2195</td>
#       <td>778</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>332</td>
#       <td>555</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2572</td>
#       <td>1097</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>48</td>
#       <td>1577</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1720</td>
#       <td>1858</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>300</td>
#       <td>2453</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1679</td>
#       <td>2592</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>302</td>
#       <td>422</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>2069</td>
#       <td>2526</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1729</td>
#       <td>1703</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2790</td>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>982</td>
#       <td>1347</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>696</td>
#       <td>705</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2373</td>
#       <td>2673</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>964</td>
#       <td>1433</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>677</td>
#       <td>814</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2772</td>
#       <td>2613</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>8999970</th>
#       <td>2467</td>
#       <td>340</td>
#     </tr>
#     <tr>
#       <th>8999971</th>
#       <td>1469</td>
#       <td>516</td>
#     </tr>
#     <tr>
#       <th>8999972</th>
#       <td>479</td>
#       <td>516</td>
#     </tr>
#     <tr>
#       <th>8999973</th>
#       <td>2433</td>
#       <td>758</td>
#     </tr>
#     <tr>
#       <th>8999974</th>
#       <td>575</td>
#       <td>758</td>
#     </tr>
#     <tr>
#       <th>8999975</th>
#       <td>730</td>
#       <td>2395</td>
#     </tr>
#     <tr>
#       <th>8999976</th>
#       <td>2104</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999977</th>
#       <td>2737</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999978</th>
#       <td>2250</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999979</th>
#       <td>1817</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999980</th>
#       <td>1928</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999981</th>
#       <td>2396</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999982</th>
#       <td>1044</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999983</th>
#       <td>573</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999984</th>
#       <td>2938</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999985</th>
#       <td>1721</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999986</th>
#       <td>1618</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999987</th>
#       <td>257</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999988</th>
#       <td>1256</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999989</th>
#       <td>1682</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999990</th>
#       <td>2465</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999991</th>
#       <td>225</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999992</th>
#       <td>1596</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999993</th>
#       <td>2663</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999994</th>
#       <td>1202</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999995</th>
#       <td>1607</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999996</th>
#       <td>2763</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999997</th>
#       <td>1772</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999998</th>
#       <td>1890</td>
#       <td>668</td>
#     </tr>
#     <tr>
#       <th>8999999</th>
#       <td>1598</td>
#       <td>559</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G3k (input data)
# ╨╥    ▚  TC_ifr0 (3 ms)
# ╥╨    ▚  TC_ifr1 (23 ms)
# ╨╥╥   ▚  TC_ifr2 (98 ms)
# ╥╨║   ▚  PrevTC_ifr3 (6 ms)
# ║╥╨╥╥ ▚  TC_ifr3 (308 ms)
# ╨╨ ║║ ▚  Done_ifr4 (165 ms) 3 / ∞ / stop.
# ╥╥╥╨║ ▚  TC_ifr4 (724 ms) 3 / ∞ / stop.
# ║║║╥╨ ▚  PrevTC_ifr4 (55 ms) 3 / ∞ / stop.
# ╨║║║  ▚  PrevTC_ifr5 (35 ms) 3 / ∞ / stop.
# ╥╨║║  ▚  TC_ifr5 (724 ms) 3 / ∞ / stop.
# ║ ╨╨  ▚  Done_ifr5 (209 ms) 2 / ∞ / stop.
# ╨     ▚  TC (840 ms)
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at TC_sql variable.
# The following table is stored at TC variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>371</td>
#       <td>3577</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3324</td>
#       <td>2395</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1781</td>
#       <td>2812</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2131</td>
#       <td>1370</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3460</td>
#       <td>2456</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1523</td>
#       <td>2905</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3632</td>
#       <td>3018</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>3328</td>
#       <td>2277</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1658</td>
#       <td>1025</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>348</td>
#       <td>2770</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2209</td>
#       <td>1426</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>492</td>
#       <td>2806</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>3905</td>
#       <td>560</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1532</td>
#       <td>789</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1916</td>
#       <td>2119</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2693</td>
#       <td>714</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>209</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1568</td>
#       <td>2338</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2841</td>
#       <td>329</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>508</td>
#       <td>3593</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1794</td>
#       <td>3321</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1423</td>
#       <td>1285</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>2922</td>
#       <td>1036</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2264</td>
#       <td>2438</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>3062</td>
#       <td>3534</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>3238</td>
#       <td>1891</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2012</td>
#       <td>1557</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2546</td>
#       <td>1303</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2678</td>
#       <td>2558</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1769</td>
#       <td>2290</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>15995970</th>
#       <td>371</td>
#       <td>1214</td>
#     </tr>
#     <tr>
#       <th>15995971</th>
#       <td>839</td>
#       <td>986</td>
#     </tr>
#     <tr>
#       <th>15995972</th>
#       <td>2173</td>
#       <td>3799</td>
#     </tr>
#     <tr>
#       <th>15995973</th>
#       <td>3305</td>
#       <td>3799</td>
#     </tr>
#     <tr>
#       <th>15995974</th>
#       <td>45</td>
#       <td>2686</td>
#     </tr>
#     <tr>
#       <th>15995975</th>
#       <td>659</td>
#       <td>2981</td>
#     </tr>
#     <tr>
#       <th>15995976</th>
#       <td>2743</td>
#       <td>926</td>
#     </tr>
#     <tr>
#       <th>15995977</th>
#       <td>3298</td>
#       <td>2686</td>
#     </tr>
#     <tr>
#       <th>15995978</th>
#       <td>2904</td>
#       <td>3477</td>
#     </tr>
#     <tr>
#       <th>15995979</th>
#       <td>1289</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995980</th>
#       <td>2657</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995981</th>
#       <td>228</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995982</th>
#       <td>1193</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995983</th>
#       <td>2060</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995984</th>
#       <td>190</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995985</th>
#       <td>3871</td>
#       <td>3914</td>
#     </tr>
#     <tr>
#       <th>15995986</th>
#       <td>89</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995987</th>
#       <td>3645</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995988</th>
#       <td>2768</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995989</th>
#       <td>111</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995990</th>
#       <td>3932</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995991</th>
#       <td>397</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995992</th>
#       <td>1860</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995993</th>
#       <td>3019</td>
#       <td>3136</td>
#     </tr>
#     <tr>
#       <th>15995994</th>
#       <td>119</td>
#       <td>702</td>
#     </tr>
#     <tr>
#       <th>15995995</th>
#       <td>1904</td>
#       <td>978</td>
#     </tr>
#     <tr>
#       <th>15995996</th>
#       <td>1038</td>
#       <td>2981</td>
#     </tr>
#     <tr>
#       <th>15995997</th>
#       <td>340</td>
#       <td>3799</td>
#     </tr>
#     <tr>
#       <th>15995998</th>
#       <td>3287</td>
#       <td>3799</td>
#     </tr>
#     <tr>
#       <th>15995999</th>
#       <td>812</td>
#       <td>3799</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G4k (input data)
# ╨╥    ▚  TC_ifr0 (4 ms)
# ╥╨    ▚  TC_ifr1 (28 ms)
# ╨╥╥   ▚  TC_ifr2 (95 ms)
# ╥╨║   ▚  PrevTC_ifr3 (11 ms)
# ║╥╨╥╥ ▚  TC_ifr3 (442 ms)
# ╨╨ ║║ ▚  Done_ifr4 (287 ms) 3 / ∞ / stop.
# ╥╥╥╨║ ▚  TC_ifr4 (1332 ms) 3 / ∞ / stop.
# ║║║╥╨ ▚  PrevTC_ifr4 (58 ms) 3 / ∞ / stop.
# ╨║║║  ▚  PrevTC_ifr5 (50 ms) 3 / ∞ / stop.
# ╥╨║║  ▚  TC_ifr5 (1351 ms) 3 / ∞ / stop.
# ║ ╨╨  ▚  Done_ifr5 (360 ms) 3 / ∞ / stop.
# ╨     ▚  TC (1457 ms)
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at TC_sql variable.
# The following table is stored at TC variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4140</td>
#       <td>727</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4906</td>
#       <td>4627</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>622</td>
#       <td>3981</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>686</td>
#       <td>3233</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2964</td>
#       <td>1894</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3544</td>
#       <td>3842</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2554</td>
#       <td>1365</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1831</td>
#       <td>1809</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2434</td>
#       <td>4558</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1868</td>
#       <td>3756</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1182</td>
#       <td>4961</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2862</td>
#       <td>3790</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2590</td>
#       <td>2458</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2421</td>
#       <td>3195</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2751</td>
#       <td>764</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2679</td>
#       <td>1592</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>3794</td>
#       <td>4229</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>4424</td>
#       <td>2324</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>869</td>
#       <td>2755</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>148</td>
#       <td>4249</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>3025</td>
#       <td>193</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>3217</td>
#       <td>1899</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>3707</td>
#       <td>1282</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>475</td>
#       <td>2214</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>88</td>
#       <td>858</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>264</td>
#       <td>2354</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1519</td>
#       <td>1066</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>4946</td>
#       <td>4335</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1496</td>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1970</td>
#       <td>4070</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>24994970</th>
#       <td>1619</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994971</th>
#       <td>4608</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994972</th>
#       <td>1213</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994973</th>
#       <td>4318</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994974</th>
#       <td>2086</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994975</th>
#       <td>774</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994976</th>
#       <td>899</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994977</th>
#       <td>3169</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994978</th>
#       <td>2655</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994979</th>
#       <td>4450</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994980</th>
#       <td>4591</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994981</th>
#       <td>376</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994982</th>
#       <td>2176</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994983</th>
#       <td>4880</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994984</th>
#       <td>1026</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994985</th>
#       <td>3514</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994986</th>
#       <td>3650</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994987</th>
#       <td>1093</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994988</th>
#       <td>4575</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994989</th>
#       <td>3369</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994990</th>
#       <td>1472</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994991</th>
#       <td>2797</td>
#       <td>4684</td>
#     </tr>
#     <tr>
#       <th>24994992</th>
#       <td>4528</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>24994993</th>
#       <td>2844</td>
#       <td>4427</td>
#     </tr>
#     <tr>
#       <th>24994994</th>
#       <td>4880</td>
#       <td>4427</td>
#     </tr>
#     <tr>
#       <th>24994995</th>
#       <td>1628</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>24994996</th>
#       <td>4491</td>
#       <td>4427</td>
#     </tr>
#     <tr>
#       <th>24994997</th>
#       <td>3679</td>
#       <td>378</td>
#     </tr>
#     <tr>
#       <th>24994998</th>
#       <td>4614</td>
#       <td>378</td>
#     </tr>
#     <tr>
#       <th>24994999</th>
#       <td>3407</td>
#       <td>378</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G5k (input data)
# ╨╥    ▚  TC_ifr0 (4 ms)
# ╥╨    ▚  TC_ifr1 (36 ms)
# ╨╥╥   ▚  TC_ifr2 (114 ms)
# ╥╨║   ▚  PrevTC_ifr3 (16 ms)
# ║╥╨╥╥ ▚  TC_ifr3 (584 ms)
# ╨╨ ║║ ▚  Done_ifr4 (426 ms) 3 / ∞ / stop.
# ╥╥╥╨║ ▚  TC_ifr4 (2174 ms) 3 / ∞ / stop.
# ║║║╥╨ ▚  PrevTC_ifr4 (42 ms) 3 / ∞ / stop.
# ╨║║║  ▚  PrevTC_ifr5 (56 ms) 3 / ∞ / stop.
# ╥╨║║  ▚  TC_ifr5 (2160 ms) 3 / ∞ / stop.
# ║ ╨╨  ▚  Done_ifr5 (497 ms) 3 / ∞ / stop.
# ╨     ▚  TC (2427 ms)
# [     Execution complete.      ]                              </pre></div>
#
#  === Timing for Transitive Closure ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | G1k     | 1.8763943879999943 |
# | G2k     | 3.617054680000024  |
# | G3k     | 7.230493697999918  |
# | G4k     | 12.564421521999975 |
# | G5k     | 19.55763669199996  |
# +---------+--------------------+

# %%
# %%loop ("Pairwise Distances", graphs)
# %%logica D
#
# @AttachDatabase("db", "graphs.db");
#
# G(a, b) :- db.{loop_parameter}(a, b);
#
# @Recursive(D, ∞, stop: Done);
# D(a, b) Min= 1 :- G(a, b);
# D(a, c) Min= D(a, b) + 1 :- G(b, c);
#
# PrevD(a, b) :- D(a, b);
#
# Done() :- D(a, b) => PrevD(a, b);
# Out:
# Query is stored at D_sql variable.
# The following table is stored at D variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>471</td>
#       <td>966</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>399</td>
#       <td>731</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>969</td>
#       <td>313</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>630</td>
#       <td>953</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>41</td>
#       <td>215</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>861</td>
#       <td>679</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>558</td>
#       <td>186</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>472</td>
#       <td>89</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>416</td>
#       <td>15</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>706</td>
#       <td>999</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>486</td>
#       <td>815</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>980</td>
#       <td>699</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>646</td>
#       <td>285</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>779</td>
#       <td>68</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>616</td>
#       <td>252</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>902</td>
#       <td>563</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>776</td>
#       <td>874</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>925</td>
#       <td>652</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>725</td>
#       <td>762</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>286</td>
#       <td>846</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>926</td>
#       <td>452</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>220</td>
#       <td>30</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>390</td>
#       <td>806</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>996</td>
#       <td>454</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>898</td>
#       <td>90</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>866</td>
#       <td>27</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>546</td>
#       <td>303</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>816</td>
#       <td>115</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>174</td>
#       <td>246</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>952</td>
#       <td>536</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>998970</th>
#       <td>353</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998971</th>
#       <td>725</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998972</th>
#       <td>548</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998973</th>
#       <td>843</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998974</th>
#       <td>324</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998975</th>
#       <td>7</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998976</th>
#       <td>85</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998977</th>
#       <td>179</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998978</th>
#       <td>45</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998979</th>
#       <td>649</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998980</th>
#       <td>364</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998981</th>
#       <td>898</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998982</th>
#       <td>280</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998983</th>
#       <td>517</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998984</th>
#       <td>974</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998985</th>
#       <td>31</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998986</th>
#       <td>624</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998987</th>
#       <td>532</td>
#       <td>320</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>998988</th>
#       <td>121</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998989</th>
#       <td>205</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998990</th>
#       <td>781</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998991</th>
#       <td>6</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998992</th>
#       <td>765</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998993</th>
#       <td>729</td>
#       <td>320</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>998994</th>
#       <td>668</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998995</th>
#       <td>49</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998996</th>
#       <td>172</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>998997</th>
#       <td>659</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998998</th>
#       <td>578</td>
#       <td>320</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>998999</th>
#       <td>219</td>
#       <td>320</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G1k (input data)
# ╨╥    ▚  D_ifr0 (3 ms)
# ╥╨    ▚  D_ifr1 (11 ms)
# ╨╥╥   ▚  D_ifr2 (91 ms)
# ╥╨║   ▚  PrevD_ifr3 (3 ms)
# ║╥╨╥╥ ▚  D_ifr3 (120 ms)
# ║╨╥║║ ▚  PrevD_ifr4 (4 ms) 3 / ∞ / stop.
# ╨ ║╨║ ▚  Done_ifr4 (46 ms) 2 / ∞ / stop.
# ╥╥║╥╨ ▚  D_ifr4 (149 ms) 3 / ∞ / stop.
# ╨║║║╥ ▚  D_ifr5 (162 ms) 3 / ∞ / stop.
#  ╨║║║ ▚  PrevD_ifr5 (11 ms) 3 / ∞ / stop.
#   ║║╨ ▚  D (139 ms)
#   ╨╨  ▚  Done_ifr5 (38 ms) 2 / ∞ / stop.
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at D_sql variable.
# The following table is stored at D variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>136</td>
#       <td>843</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1379</td>
#       <td>864</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>589</td>
#       <td>1751</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>784</td>
#       <td>859</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1012</td>
#       <td>898</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>591</td>
#       <td>827</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>309</td>
#       <td>942</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>379</td>
#       <td>1439</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1169</td>
#       <td>204</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1433</td>
#       <td>1216</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>435</td>
#       <td>615</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1084</td>
#       <td>1929</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>278</td>
#       <td>468</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1881</td>
#       <td>1571</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>481</td>
#       <td>1423</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>777</td>
#       <td>404</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1052</td>
#       <td>1277</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1402</td>
#       <td>1219</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1131</td>
#       <td>1823</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1733</td>
#       <td>1082</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>527</td>
#       <td>1923</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1381</td>
#       <td>1354</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1323</td>
#       <td>1991</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>822</td>
#       <td>1951</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>575</td>
#       <td>1828</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1527</td>
#       <td>507</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>864</td>
#       <td>1052</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>959</td>
#       <td>1778</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>885</td>
#       <td>57</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>765</td>
#       <td>1219</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>3997970</th>
#       <td>1389</td>
#       <td>210</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997971</th>
#       <td>1160</td>
#       <td>586</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997972</th>
#       <td>625</td>
#       <td>210</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997973</th>
#       <td>380</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997974</th>
#       <td>53</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997975</th>
#       <td>1045</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997976</th>
#       <td>208</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997977</th>
#       <td>941</td>
#       <td>66</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997978</th>
#       <td>1996</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997979</th>
#       <td>1635</td>
#       <td>584</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3997980</th>
#       <td>380</td>
#       <td>584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997981</th>
#       <td>656</td>
#       <td>584</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3997982</th>
#       <td>1548</td>
#       <td>584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997983</th>
#       <td>196</td>
#       <td>584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997984</th>
#       <td>954</td>
#       <td>584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997985</th>
#       <td>1841</td>
#       <td>584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997986</th>
#       <td>1162</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997987</th>
#       <td>372</td>
#       <td>66</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997988</th>
#       <td>254</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997989</th>
#       <td>1945</td>
#       <td>66</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997990</th>
#       <td>922</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997991</th>
#       <td>589</td>
#       <td>66</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997992</th>
#       <td>1720</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997993</th>
#       <td>415</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997994</th>
#       <td>1898</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997995</th>
#       <td>1650</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997996</th>
#       <td>1374</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997997</th>
#       <td>1541</td>
#       <td>469</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3997998</th>
#       <td>1475</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3997999</th>
#       <td>1100</td>
#       <td>469</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G2k (input data)
# ╨╥    ▚  D_ifr0 (3 ms)
# ╥╨    ▚  D_ifr1 (18 ms)
# ╨╥╥   ▚  D_ifr2 (110 ms)
# ╥╨║   ▚  PrevD_ifr3 (5 ms)
# ║╥╨╥╥ ▚  D_ifr3 (237 ms)
# ║╨╥║║ ▚  PrevD_ifr4 (24 ms) 3 / ∞ / stop.
# ╨ ║╨║ ▚  Done_ifr4 (99 ms) 2 / ∞ / stop.
# ╥╥║╥╨ ▚  D_ifr4 (384 ms) 3 / ∞ / stop.
# ╨║║║╥ ▚  D_ifr5 (392 ms) 3 / ∞ / stop.
#  ╨║║║ ▚  PrevD_ifr5 (8 ms) 3 / ∞ / stop.
#   ║║╨ ▚  D (408 ms)
#   ╨╨  ▚  Done_ifr5 (107 ms) 2 / ∞ / stop.
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at D_sql variable.
# The following table is stored at D variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>275</td>
#       <td>978</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2774</td>
#       <td>2995</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2184</td>
#       <td>754</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>985</td>
#       <td>539</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2037</td>
#       <td>1007</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2774</td>
#       <td>2141</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1366</td>
#       <td>691</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>482</td>
#       <td>1963</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2054</td>
#       <td>1596</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1231</td>
#       <td>2948</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>649</td>
#       <td>2151</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1480</td>
#       <td>588</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>324</td>
#       <td>1013</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2460</td>
#       <td>456</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2883</td>
#       <td>766</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2296</td>
#       <td>701</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1150</td>
#       <td>2412</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>190</td>
#       <td>2642</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1586</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1379</td>
#       <td>22</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1624</td>
#       <td>734</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>947</td>
#       <td>2536</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1098</td>
#       <td>1689</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>527</td>
#       <td>2923</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1319</td>
#       <td>818</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>2760</td>
#       <td>2097</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>264</td>
#       <td>1354</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2269</td>
#       <td>155</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2316</td>
#       <td>1910</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2844</td>
#       <td>1818</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>8999970</th>
#       <td>1669</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999971</th>
#       <td>1113</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999972</th>
#       <td>1533</td>
#       <td>224</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999973</th>
#       <td>2810</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999974</th>
#       <td>2427</td>
#       <td>224</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999975</th>
#       <td>2529</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999976</th>
#       <td>1221</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999977</th>
#       <td>402</td>
#       <td>224</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999978</th>
#       <td>501</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999979</th>
#       <td>269</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999980</th>
#       <td>773</td>
#       <td>224</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999981</th>
#       <td>1091</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999982</th>
#       <td>2453</td>
#       <td>2584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999983</th>
#       <td>2813</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999984</th>
#       <td>927</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999985</th>
#       <td>2921</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999986</th>
#       <td>1610</td>
#       <td>2584</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999987</th>
#       <td>1868</td>
#       <td>2584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999988</th>
#       <td>1897</td>
#       <td>2584</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999989</th>
#       <td>309</td>
#       <td>224</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999990</th>
#       <td>1687</td>
#       <td>224</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999991</th>
#       <td>1939</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999992</th>
#       <td>1642</td>
#       <td>224</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999993</th>
#       <td>2206</td>
#       <td>559</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999994</th>
#       <td>923</td>
#       <td>559</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999995</th>
#       <td>196</td>
#       <td>559</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999996</th>
#       <td>1481</td>
#       <td>559</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>8999997</th>
#       <td>313</td>
#       <td>559</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999998</th>
#       <td>2306</td>
#       <td>559</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8999999</th>
#       <td>2265</td>
#       <td>389</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G3k (input data)
# ╨╥    ▚  D_ifr0 (4 ms)
# ╥╨    ▚  D_ifr1 (29 ms)
# ╨╥╥   ▚  D_ifr2 (120 ms)
# ╥╨║   ▚  PrevD_ifr3 (6 ms)
# ║╥╨╥╥ ▚  D_ifr3 (343 ms)
# ║╨╥║║ ▚  PrevD_ifr4 (16 ms) 3 / ∞ / stop.
# ╨ ║╨║ ▚  Done_ifr4 (192 ms) 2 / ∞ / stop.
# ╥╥║╥╨ ▚  D_ifr4 (927 ms) 3 / ∞ / stop.
# ╨║║║╥ ▚  D_ifr5 (941 ms) 3 / ∞ / stop.
#  ╨║║║ ▚  PrevD_ifr5 (20 ms) 3 / ∞ / stop.
#   ║║╨ ▚  D (995 ms)
#   ╨╨  ▚  Done_ifr5 (167 ms) 2 / ∞ / stop.
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at D_sql variable.
# The following table is stored at D variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1826</td>
#       <td>1104</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>59</td>
#       <td>1395</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2471</td>
#       <td>2966</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3210</td>
#       <td>84</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2774</td>
#       <td>995</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3781</td>
#       <td>1142</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2982</td>
#       <td>1367</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1755</td>
#       <td>175</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>3812</td>
#       <td>507</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2230</td>
#       <td>1068</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2159</td>
#       <td>2322</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>77</td>
#       <td>3112</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>325</td>
#       <td>567</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>764</td>
#       <td>632</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2744</td>
#       <td>273</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>3486</td>
#       <td>2815</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2781</td>
#       <td>1680</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>3729</td>
#       <td>977</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>3266</td>
#       <td>3864</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2316</td>
#       <td>2858</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2985</td>
#       <td>2141</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>2043</td>
#       <td>669</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>3425</td>
#       <td>1606</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>3785</td>
#       <td>3867</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2056</td>
#       <td>3230</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>3792</td>
#       <td>1743</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>98</td>
#       <td>3959</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2408</td>
#       <td>3631</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1946</td>
#       <td>2013</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>3567</td>
#       <td>1160</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>15995970</th>
#       <td>344</td>
#       <td>3346</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995971</th>
#       <td>3314</td>
#       <td>3346</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995972</th>
#       <td>819</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995973</th>
#       <td>1882</td>
#       <td>3346</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995974</th>
#       <td>2655</td>
#       <td>471</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995975</th>
#       <td>716</td>
#       <td>471</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995976</th>
#       <td>1827</td>
#       <td>3387</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995977</th>
#       <td>3972</td>
#       <td>3387</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995978</th>
#       <td>219</td>
#       <td>978</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995979</th>
#       <td>3675</td>
#       <td>2909</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995980</th>
#       <td>614</td>
#       <td>3136</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995981</th>
#       <td>3945</td>
#       <td>3136</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995982</th>
#       <td>2500</td>
#       <td>3136</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995983</th>
#       <td>1575</td>
#       <td>1105</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995984</th>
#       <td>3042</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995985</th>
#       <td>1004</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995986</th>
#       <td>323</td>
#       <td>3346</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995987</th>
#       <td>3328</td>
#       <td>2037</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995988</th>
#       <td>2268</td>
#       <td>2037</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995989</th>
#       <td>2234</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995990</th>
#       <td>1083</td>
#       <td>3346</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995991</th>
#       <td>2456</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995992</th>
#       <td>3067</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995993</th>
#       <td>2028</td>
#       <td>3346</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>15995994</th>
#       <td>2330</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995995</th>
#       <td>3769</td>
#       <td>3346</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>15995996</th>
#       <td>788</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995997</th>
#       <td>1305</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>15995998</th>
#       <td>3600</td>
#       <td>3346</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>15995999</th>
#       <td>1241</td>
#       <td>3346</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G4k (input data)
# ╨╥    ▚  D_ifr0 (4 ms)
# ╥╨    ▚  D_ifr1 (37 ms)
# ╨╥╥   ▚  D_ifr2 (120 ms)
# ╥╨║   ▚  PrevD_ifr3 (10 ms)
# ║╥╨╥╥ ▚  D_ifr3 (498 ms)
# ║╨╥║║ ▚  PrevD_ifr4 (26 ms) 3 / ∞ / stop.
# ╨ ║╨║ ▚  Done_ifr4 (274 ms) 2 / ∞ / stop.
# ╥╥║╥╨ ▚  D_ifr4 (1803 ms) 3 / ∞ / stop.
# ╨║║║╥ ▚  D_ifr5 (1666 ms) 3 / ∞ / stop.
#  ╨║║║ ▚  PrevD_ifr5 (46 ms) 3 / ∞ / stop.
#   ║║╨ ▚  D (1864 ms)
#   ╨╨  ▚  Done_ifr5 (319 ms) 3 / ∞ / stop.
# [     Execution complete.      ]                              </pre></div>
#
# Query is stored at D_sql variable.
# The following table is stored at D variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col0</th>
#       <th>col1</th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2379</td>
#       <td>4010</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>781</td>
#       <td>967</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1978</td>
#       <td>3870</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4233</td>
#       <td>1699</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1286</td>
#       <td>2476</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1348</td>
#       <td>474</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1916</td>
#       <td>3457</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2125</td>
#       <td>3540</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2381</td>
#       <td>2207</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2707</td>
#       <td>2646</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>384</td>
#       <td>333</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2663</td>
#       <td>2428</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1750</td>
#       <td>3449</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1145</td>
#       <td>2176</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>4553</td>
#       <td>499</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>4125</td>
#       <td>297</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1758</td>
#       <td>1210</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>4517</td>
#       <td>1094</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>3440</td>
#       <td>2037</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2124</td>
#       <td>1961</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>4365</td>
#       <td>1182</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>379</td>
#       <td>1068</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>3995</td>
#       <td>4642</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1939</td>
#       <td>2534</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2052</td>
#       <td>3014</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>4798</td>
#       <td>2626</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2936</td>
#       <td>3287</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>3605</td>
#       <td>1707</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>817</td>
#       <td>974</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>4124</td>
#       <td>1913</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>24994970</th>
#       <td>4290</td>
#       <td>2418</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994971</th>
#       <td>1613</td>
#       <td>978</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994972</th>
#       <td>3418</td>
#       <td>978</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994973</th>
#       <td>3811</td>
#       <td>2340</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994974</th>
#       <td>1317</td>
#       <td>2340</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994975</th>
#       <td>833</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994976</th>
#       <td>3530</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994977</th>
#       <td>3076</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994978</th>
#       <td>1981</td>
#       <td>378</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>24994979</th>
#       <td>4205</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994980</th>
#       <td>1202</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994981</th>
#       <td>383</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994982</th>
#       <td>2811</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994983</th>
#       <td>1697</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994984</th>
#       <td>2259</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994985</th>
#       <td>2189</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994986</th>
#       <td>751</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994987</th>
#       <td>1810</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994988</th>
#       <td>3200</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994989</th>
#       <td>384</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994990</th>
#       <td>1631</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994991</th>
#       <td>736</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994992</th>
#       <td>365</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994993</th>
#       <td>1450</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994994</th>
#       <td>4704</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24994995</th>
#       <td>2250</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994996</th>
#       <td>1738</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994997</th>
#       <td>3523</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994998</th>
#       <td>1306</td>
#       <td>378</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>24994999</th>
#       <td>1137</td>
#       <td>378</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥     ▚  db.G5k (input data)
# ╨╥    ▚  D_ifr0 (10 ms)
# ╥╨    ▚  D_ifr1 (47 ms)
# ╨╥╥   ▚  D_ifr2 (164 ms)
# ╥╨║   ▚  PrevD_ifr3 (21 ms)
# ║╥╨╥╥ ▚  D_ifr3 (675 ms)
# ║╨╥║║ ▚  PrevD_ifr4 (64 ms) 3 / ∞ / stop.
# ╨ ║╨║ ▚  Done_ifr4 (449 ms) 2 / ∞ / stop.
# ╥╥║╥╨ ▚  D_ifr4 (2923 ms) 3 / ∞ / stop.
# ╨║║║╥ ▚  D_ifr5 (2815 ms) 3 / ∞ / stop.
#  ╨║║║ ▚  PrevD_ifr5 (105 ms) 3 / ∞ / stop.
#   ║║╨ ▚  D (3091 ms)
#   ╨╨  ▚  Done_ifr5 (498 ms) 3 / ∞ / stop.
# [     Execution complete.      ]                              </pre></div>
#
#  === Timing for Pairwise Distances ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | G1k     | 2.099346245999982  |
# | G2k     | 4.338347781999914  |
# | G3k     | 8.60555926699999   |
# | G4k     | 15.257616865000045 |
# | G5k     | 23.63516611        |
# +---------+--------------------+

# %%
from logica.common import graph

graph.DirectedGraph(Tree)
# Out:
#   <style>
#   .vis .overlay{position:absolute;top:0;left:0;width:100%;height:100%;z-index:10}.vis-active{box-shadow:0 0 10px #86d5f8}.vis [class*=span]{min-height:0;width:auto}div.vis-configuration{position:relative;display:block;float:left;font-size:12px}div.vis-configuration-wrapper{display:block;width:700px}div.vis-configuration-wrapper::after{clear:both;content:"";display:block}div.vis-configuration.vis-config-option-container{display:block;width:495px;background-color:#fff;border:2px solid #f7f8fa;border-radius:4px;margin-top:20px;left:10px;padding-left:5px}div.vis-configuration.vis-config-button{display:block;width:495px;height:25px;vertical-align:middle;line-height:25px;background-color:#f7f8fa;border:2px solid #ceced0;border-radius:4px;margin-top:20px;left:10px;padding-left:5px;cursor:pointer;margin-bottom:30px}div.vis-configuration.vis-config-button.hover{background-color:#4588e6;border:2px solid #214373;color:#fff}div.vis-configuration.vis-config-item{display:block;float:left;width:495px;height:25px;vertical-align:middle;line-height:25px}div.vis-configuration.vis-config-item.vis-config-s2{left:10px;background-color:#f7f8fa;padding-left:5px;border-radius:3px}div.vis-configuration.vis-config-item.vis-config-s3{left:20px;background-color:#e4e9f0;padding-left:5px;border-radius:3px}div.vis-configuration.vis-config-item.vis-config-s4{left:30px;background-color:#cfd8e6;padding-left:5px;border-radius:3px}div.vis-configuration.vis-config-header{font-size:18px;font-weight:700}div.vis-configuration.vis-config-label{width:120px;height:25px;line-height:25px}div.vis-configuration.vis-config-label.vis-config-s3{width:110px}div.vis-configuration.vis-config-label.vis-config-s4{width:100px}div.vis-configuration.vis-config-colorBlock{top:1px;width:30px;height:19px;border:1px solid #444;border-radius:2px;padding:0;margin:0;cursor:pointer}input.vis-configuration.vis-config-checkbox{left:-5px}input.vis-configuration.vis-config-rangeinput{position:relative;top:-5px;width:60px;padding:1px;margin:0;pointer-events:none}input.vis-configuration.vis-config-range{-webkit-appearance:none;border:0 solid #fff;background-color:rgba(0,0,0,0);width:300px;height:20px}input.vis-configuration.vis-config-range::-webkit-slider-runnable-track{width:300px;height:5px;background:#dedede;background:-moz-linear-gradient(top,#dedede 0,#c8c8c8 99%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#dedede),color-stop(99%,#c8c8c8));background:-webkit-linear-gradient(top,#dedede 0,#c8c8c8 99%);background:-o-linear-gradient(top,#dedede 0,#c8c8c8 99%);background:-ms-linear-gradient(top,#dedede 0,#c8c8c8 99%);background:linear-gradient(to bottom,#dedede 0,#c8c8c8 99%);border:1px solid #999;box-shadow:#aaa 0 0 3px 0;border-radius:3px}input.vis-configuration.vis-config-range::-webkit-slider-thumb{-webkit-appearance:none;border:1px solid #14334b;height:17px;width:17px;border-radius:50%;background:#3876c2;background:-moz-linear-gradient(top,#3876c2 0,#385380 100%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#3876c2),color-stop(100%,#385380));background:-webkit-linear-gradient(top,#3876c2 0,#385380 100%);background:-o-linear-gradient(top,#3876c2 0,#385380 100%);background:-ms-linear-gradient(top,#3876c2 0,#385380 100%);background:linear-gradient(to bottom,#3876c2 0,#385380 100%);box-shadow:#111927 0 0 1px 0;margin-top:-7px}input.vis-configuration.vis-config-range:focus{outline:0}input.vis-configuration.vis-config-range:focus::-webkit-slider-runnable-track{background:#9d9d9d;background:-moz-linear-gradient(top,#9d9d9d 0,#c8c8c8 99%);background:-webkit-gradient(linear,left top,left bottom,color-stop(0,#9d9d9d),color-stop(99%,#c8c8c8));background:-webkit-linear-gradient(top,#9d9d9d 0,#c8c8c8 99%);background:-o-linear-gradient(top,#9d9d9d 0,#c8c8c8 99%);background:-ms-linear-gradient(top,#9d9d9d 0,#c8c8c8 99%);background:linear-gradient(to bottom,#9d9d9d 0,#c8c8c8 99%)}input.vis-configuration.vis-config-range::-moz-range-track{width:300px;height:1 ...

# %%
# %%loop ("Same Generation", trees)
# %%logica SGCheck, SGGold
#
#
# @AttachDatabase("db", "graphs.db");
#
# Tree(x, y) :- db.{loop_parameter}(x, y);
# #Tree(x, y) :- db.Tree12(x, y);
#
# Node(x) distinct :- x in [a, b], Tree(a, b), Str(x);
#
# # Tree("a", "b");
# # Tree("a", "c");
# # Tree("c", "d");
#
# @Recursive(SG, ∞, stop: Done);
# SG(x, y) distinct :- Tree(a, x), Tree(a, y);
# SG(x, y) distinct :- SG(a, b), Tree(a, x), Tree(b, y);
# PrevSG(x, y) :- SG(x, y);
# Done() :- Sum{ 1 :- SG(x, y) } == Sum{ 1 :- PrevSG(x, y) };
#
# SGCheck() += 1 :- SG();
# SGGold() += 1 :- Node(a), Node(b), Length(a) == Length(b);
# Out:
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14656</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14657</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥    ▚  db.Tree7 (input data)
# ╨║    ▚  SGGold (14 ms)
# ╥╨    ▚  SG_ifr0 (2 ms)
# ╨╥    ▚  SG_ifr1 (19 ms)
# ╥╨╥   ▚  SG_ifr2 (3 ms)
# ╨╥║╥╥ ▚  SG_ifr3 (8 ms)
# ╥║╨║║ ▚  PrevSG_ifr3 (1 ms)
# ╨╨ ║║ ▚  Done_ifr4 (1 ms) 3 / ∞ / stop.
# ╥  ╨║ ▚  PrevSG_ifr4 (2 ms) 3 / ∞ / stop.
# ║╥╥╥╨ ▚  SG_ifr4 (6 ms) 3 / ∞ / stop.
# ║╨║║╥ ▚  SG_ifr5 (6 ms) 3 / ∞ / stop.
# ╨ ╨║║ ▚  Done_ifr5 (1 ms) 2 / ∞ / stop.
#    ╨║ ▚  PrevSG_ifr5 (2 ms) 3 / ∞ / stop.
# ╥   ╨ ▚  SG (5 ms)
# ╨     ▚  SGCheck (1 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99337</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99338</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥    ▚  db.Tree8 (input data)
# ╨║    ▚  SGGold (5 ms)
# ╥╨    ▚  SG_ifr0 (2 ms)
# ╨╥    ▚  SG_ifr1 (8 ms)
# ╥╨╥   ▚  SG_ifr2 (4 ms)
# ╨╥║╥╥ ▚  SG_ifr3 (7 ms)
# ╥║╨║║ ▚  PrevSG_ifr3 (2 ms)
# ╨╨ ║║ ▚  Done_ifr4 (1 ms) 3 / ∞ / stop.
# ╥  ╨║ ▚  PrevSG_ifr4 (16 ms) 3 / ∞ / stop.
# ║╥╥╥╨ ▚  SG_ifr4 (28 ms) 3 / ∞ / stop.
# ╨╨║║  ▚  Done_ifr5 (2 ms) 3 / ∞ / stop.
# ╥ ╨║  ▚  SG_ifr5 (27 ms) 3 / ∞ / stop.
# ║  ╨  ▚  PrevSG_ifr5 (15 ms) 3 / ∞ / stop.
# ╨╥    ▚  SG (28 ms)
#  ╨    ▚  SGCheck (1 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>638093</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>638094</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥    ▚  db.Tree9 (input data)
# ╨║    ▚  SGGold (21 ms)
# ╥╨    ▚  SG_ifr0 (2 ms)
# ╨╥    ▚  SG_ifr1 (4 ms)
# ╥╨╥   ▚  SG_ifr2 (9 ms)
# ╨╥║╥╥ ▚  SG_ifr3 (15 ms)
# ╥║╨║║ ▚  PrevSG_ifr3 (5 ms)
# ╨╨ ║║ ▚  Done_ifr4 (2 ms) 4 / ∞ / stop.
# ╥  ╨║ ▚  PrevSG_ifr4 (11 ms) 4 / ∞ / stop.
# ║╥╥╥╨ ▚  SG_ifr4 (92 ms) 4 / ∞ / stop.
# ║╨║║╥ ▚  SG_ifr5 (88 ms) 4 / ∞ / stop.
# ╨ ╨║║ ▚  Done_ifr5 (2 ms) 3 / ∞ / stop.
#    ╨║ ▚  PrevSG_ifr5 (39 ms) 4 / ∞ / stop.
# ╥   ╨ ▚  SG (97 ms)
# ╨     ▚  SGCheck (1 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4153718</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4153719</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥    ▚  db.Tree10 (input data)
# ╨║    ▚  SGGold (21 ms)
# ╥╨    ▚  SG_ifr0 (4 ms)
# ╨╥    ▚  SG_ifr1 (8 ms)
# ╥╨╥   ▚  SG_ifr2 (17 ms)
# ╨╥║╥╥ ▚  SG_ifr3 (47 ms)
# ╥║╨║║ ▚  PrevSG_ifr3 (11 ms)
# ╨╨ ║║ ▚  Done_ifr4 (5 ms) 4 / ∞ / stop.
# ╥  ╨║ ▚  PrevSG_ifr4 (24 ms) 4 / ∞ / stop.
# ║╥╥╥╨ ▚  SG_ifr4 (132 ms) 4 / ∞ / stop.
# ║╨║║╥ ▚  SG_ifr5 (223 ms) 4 / ∞ / stop.
# ╨ ╨║║ ▚  Done_ifr5 (5 ms) 4 / ∞ / stop.
#    ╨║ ▚  PrevSG_ifr5 (26 ms) 4 / ∞ / stop.
# ╥   ╨ ▚  SG (142 ms)
# ╨     ▚  SGCheck (2 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26253119</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26253120</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥    ▚  db.Tree11 (input data)
# ╨║    ▚  SGGold (40 ms)
# ╥╨    ▚  SG_ifr0 (6 ms)
# ╨╥    ▚  SG_ifr1 (22 ms)
# ╥╨╥   ▚  SG_ifr2 (40 ms)
# ╨╥║╥╥ ▚  SG_ifr3 (82 ms)
# ╥║╨║║ ▚  PrevSG_ifr3 (12 ms)
# ╨╨ ║║ ▚  Done_ifr4 (24 ms) 5 / ∞ / stop.
# ╥  ╨║ ▚  PrevSG_ifr4 (174 ms) 5 / ∞ / stop.
# ║╥╥╥╨ ▚  SG_ifr4 (842 ms) 5 / ∞ / stop.
# ║╨║║╥ ▚  SG_ifr5 (796 ms) 5 / ∞ / stop.
# ╨ ╨║║ ▚  Done_ifr5 (14 ms) 4 / ∞ / stop.
#    ╨║ ▚  PrevSG_ifr5 (173 ms) 5 / ∞ / stop.
# ╥   ╨ ▚  SG (535 ms)
# ╨     ▚  SGCheck (5 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>163681848</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>163681849</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥    ▚  db.Tree12 (input data)
# ╨║    ▚  SGGold (137 ms)
# ╥╨    ▚  SG_ifr0 (16 ms)
# ╨╥    ▚  SG_ifr1 (39 ms)
# ╥╨╥   ▚  SG_ifr2 (89 ms)
# ╨╥║╥╥ ▚  SG_ifr3 (81 ms)
# ╥║╨║║ ▚  PrevSG_ifr3 (30 ms)
# ╨╨ ║║ ▚  Done_ifr4 (154 ms) 5 / ∞ / stop.
# ╥  ╨║ ▚  PrevSG_ifr4 (1173 ms) 5 / ∞ / stop.
# ║╥╥╥╨ ▚  SG_ifr4 (5607 ms) 5 / ∞ / stop.
# ║╨║║╥ ▚  SG_ifr5 (5309 ms) 5 / ∞ / stop.
# ╨ ╨║║ ▚  Done_ifr5 (137 ms) 5 / ∞ / stop.
#    ╨║ ▚  PrevSG_ifr5 (1030 ms) 5 / ∞ / stop.
# ╥   ╨ ▚  SG (5311 ms)
# ╨     ▚  SGCheck (19 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
#  === Timing for Same Generation ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | Tree7   | 0.7857960700000604 |
# | Tree8   | 0.9151512260000345 |
# | Tree9   | 1.6111061390000714 |
# | Tree10  | 2.1807925879999175 |
# | Tree11  | 7.708316269999955  |
# | Tree12  | 37.75424764900015  |
# +---------+--------------------+

# %%
timing
# Out:
# {'a': 0.00022921100003259198,
#  'b': 0.0001869599999508864,
#  'c': 0.00017046899995420972,
#  'G1k': 2.099346245999982,
#  'G2k': 4.338347781999914,
#  'G3k': 8.60555926699999,
#  'G4k': 15.257616865000045,
#  'G5k': 23.63516611,
#  'Tree7': 0.7857960700000604,
#  'Tree8': 0.9151512260000345,
#  'Tree9': 1.6111061390000714,
#  'Tree10': 2.1807925879999175,
#  'Tree11': 7.708316269999955,
#  'Tree12': 37.75424764900015}

# %%
timing
# Out:
# {'a': 0.00022921100003259198,
#  'b': 0.0001869599999508864,
#  'c': 0.00017046899995420972,
#  'G1k': 2.099346245999982,
#  'G2k': 4.338347781999914,
#  'G3k': 8.60555926699999,
#  'G4k': 15.257616865000045,
#  'G5k': 23.63516611,
#  'Tree7': 0.7857960700000604,
#  'Tree8': 0.9151512260000345,
#  'Tree9': 1.6111061390000714,
#  'Tree10': 2.1807925879999175,
#  'Tree11': 7.708316269999955,
#  'Tree12': 37.75424764900015}

# %%
# %%loop ("Same Generation Logica-style", trees)
# %%logica SGCheck, SGGold
#
#
# @AttachDatabase("db", "graphs.db");
#
# Tree(x, y) :- db.{loop_parameter}(x, y);
# #Tree(x, y) :- db.Tree7(x, y);
#
# Node(x) distinct :- x in [a, b], Tree(a, b), Str(x);
# # Tree("a", "b");
# # Tree("a", "c");
# # Tree("c", "d");
#
#
# @Recursive(Gen, ∞, stop: Done);
# Gen(x) Min= x :- Node(x);
# NextGen(Gen(x)) Min= Gen(y) :- Tree(x, y);
# Gen(y) Min= NextGen(Gen(x)) :- Tree(x, y);
#
# PrevGen(x) = Gen(x);
# Done() :- Gen(x) => Gen(x) = PrevGen(x);
#
# SG(x, y) :- Gen(x) = Gen(y);
#
#
# SGCheck() += 1 :- SG();
# SGGold() += 1 :- Node(a), Node(b), Length(a) == Length(b);
# Out:
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14657</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>14657</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥╥      ▚  db.Tree7 (input data)
# ╨║║╥     ▚  Gen_ifr0 (5 ms)
# ╥╨║║╥    ▚  Gen_ifr1 (3 ms)
# ║ ╨║║    ▚  SGGold (4 ms)
# ╨╥ ║║    ▚  NextGen_ifr2 (2 ms)
# ╥║ ╨║    ▚  NextGen_ifr1 (2 ms)
# ╨║╥╥╨    ▚  Gen_ifr2 (30 ms)
# ╥╨╨║╥    ▚  Gen_ifr3 (13 ms)
# ╨╥ ║║    ▚  NextGen_ifr4 (2 ms)
# ╥║ ╨║    ▚  NextGen_ifr3 (2 ms)
# ╨║╥╥╨╥   ▚  Gen_ifr4 (3 ms)
# ╥╨╨║╥║╥╥ ▚  Gen_ifr5 (15 ms)
# ╨╥ ║║║║║ ▚  NextGen_ifr6 (2 ms) 3 / ∞ / stop.
# ╥║ ╨║║║║ ▚  NextGen_ifr5 (2 ms)
# ║║╥ ║╨║║ ▚  PrevGen_ifr5 (0 ms)
# ║║╨ ╨ ║║ ▚  Done_ifr6 (23 ms) 3 / ∞ / stop.
# ║║╥   ╨║ ▚  PrevGen_ifr6 (0 ms) 3 / ∞ / stop.
# ╨║║╥╥╥╥╨ ▚  Gen_ifr6 (3 ms) 3 / ∞ / stop.
#  ║╨╨║║║  ▚  Done_ifr7 (3 ms) 2 / ∞ / stop.
# ╥╨  ╨║║  ▚  Gen_ifr7 (3 ms) 3 / ∞ / stop.
# ║    ╨║  ▚  PrevGen_ifr7 (0 ms) 3 / ∞ / stop.
# ║╥    ╨  ▚  NextGen_ifr7 (1 ms) 3 / ∞ / stop.
# ╨╨╥      ▚  Gen (9 ms)
#   ╨      ▚  SGCheck (1 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99338</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99338</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥╥      ▚  db.Tree8 (input data)
# ╨║║╥     ▚  Gen_ifr0 (17 ms)
# ╥╨║║╥    ▚  Gen_ifr1 (27 ms)
# ║ ╨║║    ▚  SGGold (6 ms)
# ╨╥ ║║    ▚  NextGen_ifr2 (2 ms)
# ╥║ ╨║    ▚  NextGen_ifr1 (2 ms)
# ╨║╥╥╨    ▚  Gen_ifr2 (6 ms)
# ╥╨╨║╥    ▚  Gen_ifr3 (4 ms)
# ╨╥ ║║    ▚  NextGen_ifr4 (2 ms)
# ╥║ ╨║    ▚  NextGen_ifr3 (2 ms)
# ╨║╥╥╨╥   ▚  Gen_ifr4 (3 ms)
# ╥╨╨║╥║╥╥ ▚  Gen_ifr5 (26 ms)
# ╨╥ ║║║║║ ▚  NextGen_ifr6 (2 ms) 3 / ∞ / stop.
# ╥║ ╨║║║║ ▚  NextGen_ifr5 (2 ms)
# ║║╥ ║╨║║ ▚  PrevGen_ifr5 (0 ms)
# ║║╨ ╨ ║║ ▚  Done_ifr6 (3 ms) 3 / ∞ / stop.
# ║║╥   ╨║ ▚  PrevGen_ifr6 (0 ms) 3 / ∞ / stop.
# ╨║║╥╥╥╥╨ ▚  Gen_ifr6 (3 ms) 3 / ∞ / stop.
#  ║╨╨║║║  ▚  Done_ifr7 (20 ms) 3 / ∞ / stop.
# ╥╨  ╨║║  ▚  Gen_ifr7 (3 ms) 3 / ∞ / stop.
# ║    ╨║  ▚  PrevGen_ifr7 (0 ms) 3 / ∞ / stop.
# ║╥    ╨  ▚  NextGen_ifr7 (2 ms) 3 / ∞ / stop.
# ╨╨╥      ▚  Gen (20 ms)
#   ╨      ▚  SGCheck (2 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>638094</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>638094</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥╥      ▚  db.Tree9 (input data)
# ╨║║╥╥    ▚  Gen_ifr1 (5 ms)
#  ╨║║║    ▚  SGGold (24 ms)
# ╥ ║╨║    ▚  NextGen_ifr2 (3 ms)
# ║╥╨ ║    ▚  Gen_ifr0 (4 ms)
# ║╨╥ ║    ▚  NextGen_ifr1 (3 ms)
# ║╥╨╥╨    ▚  Gen_ifr2 (6 ms)
# ╨╨╥║╥    ▚  Gen_ifr3 (4 ms)
# ╥ ╨║║    ▚  NextGen_ifr4 (3 ms)
# ║╥ ╨║    ▚  NextGen_ifr3 (2 ms)
# ║╨╥╥╨╥   ▚  Gen_ifr4 (4 ms)
# ╨╥╨║╥║╥╥ ▚  Gen_ifr5 (4 ms)
# ╥╨ ║║║║║ ▚  NextGen_ifr6 (2 ms) 4 / ∞ / stop.
# ║╥ ╨║║║║ ▚  NextGen_ifr5 (2 ms)
# ║║╥ ║╨║║ ▚  PrevGen_ifr5 (0 ms)
# ║║╨ ╨ ║║ ▚  Done_ifr6 (4 ms) 4 / ∞ / stop.
# ║║╥   ╨║ ▚  PrevGen_ifr6 (0 ms) 4 / ∞ / stop.
# ║╨║╥╥╥╥╨ ▚  Gen_ifr6 (5 ms) 4 / ∞ / stop.
# ║ ╨╨║║║  ▚  Done_ifr7 (4 ms) 3 / ∞ / stop.
# ╨╥  ╨║║  ▚  Gen_ifr7 (4 ms) 4 / ∞ / stop.
#  ║   ╨║  ▚  PrevGen_ifr7 (0 ms) 4 / ∞ / stop.
# ╥║    ╨  ▚  NextGen_ifr7 (2 ms) 4 / ∞ / stop.
# ╨╨╥      ▚  Gen (10 ms)
#   ╨      ▚  SGCheck (4 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4153719</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4153719</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥╥      ▚  db.Tree10 (input data)
# ╨║║╥     ▚  Gen_ifr0 (5 ms)
# ╥╨║║╥    ▚  Gen_ifr1 (6 ms)
# ║ ╨║║    ▚  SGGold (11 ms)
# ╨╥ ║║    ▚  NextGen_ifr2 (3 ms)
# ╥║ ╨║    ▚  NextGen_ifr1 (3 ms)
# ╨║╥╥╨    ▚  Gen_ifr2 (7 ms)
# ╥╨╨║╥    ▚  Gen_ifr3 (7 ms)
# ╨╥ ║║    ▚  NextGen_ifr4 (3 ms)
# ╥║ ╨║    ▚  NextGen_ifr3 (3 ms)
# ╨║╥╥╨╥   ▚  Gen_ifr4 (6 ms)
# ╥╨╨║╥║╥╥ ▚  Gen_ifr5 (18 ms)
# ╨╥ ║║║║║ ▚  NextGen_ifr6 (3 ms) 4 / ∞ / stop.
# ╥║ ╨║║║║ ▚  NextGen_ifr5 (3 ms)
# ║║╥ ║╨║║ ▚  PrevGen_ifr5 (1 ms)
# ║║╨ ╨ ║║ ▚  Done_ifr6 (6 ms) 4 / ∞ / stop.
# ║║╥   ╨║ ▚  PrevGen_ifr6 (1 ms) 4 / ∞ / stop.
# ╨║║╥╥╥╥╨ ▚  Gen_ifr6 (6 ms) 4 / ∞ / stop.
#  ║╨╨║║║  ▚  Done_ifr7 (5 ms) 4 / ∞ / stop.
# ╥╨  ╨║║  ▚  Gen_ifr7 (6 ms) 4 / ∞ / stop.
# ║    ╨║  ▚  PrevGen_ifr7 (1 ms) 4 / ∞ / stop.
# ║╥    ╨  ▚  NextGen_ifr7 (2 ms) 4 / ∞ / stop.
# ╨╨╥      ▚  Gen (8 ms)
#   ╨      ▚  SGCheck (21 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26253120</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26253120</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥╥      ▚  db.Tree11 (input data)
# ╨║║╥╥    ▚  Gen_ifr1 (9 ms)
#  ╨║║║    ▚  SGGold (46 ms)
# ╥ ║╨║    ▚  NextGen_ifr2 (5 ms)
# ║╥╨ ║    ▚  Gen_ifr0 (9 ms)
# ║╨╥ ║    ▚  NextGen_ifr1 (5 ms)
# ║╥╨╥╨    ▚  Gen_ifr2 (18 ms)
# ╨╨╥║╥    ▚  Gen_ifr3 (11 ms)
# ╥ ╨║║    ▚  NextGen_ifr4 (5 ms)
# ║╥ ╨║    ▚  NextGen_ifr3 (5 ms)
# ║╨╥╥╨╥   ▚  Gen_ifr4 (12 ms)
# ╨╥╨║╥║╥╥ ▚  Gen_ifr5 (11 ms)
# ╥╨ ║║║║║ ▚  NextGen_ifr6 (4 ms) 5 / ∞ / stop.
# ║╥ ╨║║║║ ▚  NextGen_ifr5 (6 ms)
# ║║╥ ║╨║║ ▚  PrevGen_ifr5 (1 ms)
# ║║╨ ╨ ║║ ▚  Done_ifr6 (7 ms) 5 / ∞ / stop.
# ║║╥   ╨║ ▚  PrevGen_ifr6 (1 ms) 5 / ∞ / stop.
# ║╨║╥╥╥╥╨ ▚  Gen_ifr6 (20 ms) 5 / ∞ / stop.
# ║ ╨╨║║║  ▚  Done_ifr7 (6 ms) 4 / ∞ / stop.
# ╨╥  ╨║║  ▚  Gen_ifr7 (9 ms) 5 / ∞ / stop.
#  ║   ╨║  ▚  PrevGen_ifr7 (1 ms) 5 / ∞ / stop.
# ╥║    ╨  ▚  NextGen_ifr7 (5 ms) 5 / ∞ / stop.
# ╨╨╥      ▚  Gen (11 ms)
#   ╨      ▚  SGCheck (127 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
# Query is stored at SGCheck_sql variable.
# The following table is stored at SGCheck variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>163681849</td>
#     </tr>
#   </tbody>
# </table>
# Query is stored at SGGold_sql variable.
# The following table is stored at SGGold variable.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>logica_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>163681849</td>
#     </tr>
#   </tbody>
# </table>
# <div style="border: 1px solid rgba(0, 0, 0, 0.3);width: fit-content;;padding: 20px;border-radius: 5px;min-width: 50em;box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.2)"><pre>╥╥╥      ▚  db.Tree12 (input data)
# ╨║║╥╥    ▚  Gen_ifr1 (25 ms)
#  ╨║║║    ▚  SGGold (118 ms)
# ╥ ║╨║    ▚  NextGen_ifr2 (8 ms)
# ║╥╨ ║    ▚  Gen_ifr0 (23 ms)
# ║╨╥ ║    ▚  NextGen_ifr1 (9 ms)
# ║╥╨╥╨    ▚  Gen_ifr2 (18 ms)
# ╨╨╥║╥    ▚  Gen_ifr3 (23 ms)
# ╥ ╨║║    ▚  NextGen_ifr4 (7 ms)
# ║╥ ╨║    ▚  NextGen_ifr3 (7 ms)
# ║╨╥╥╨╥   ▚  Gen_ifr4 (18 ms)
# ╨╥╨║╥║╥╥ ▚  Gen_ifr5 (24 ms)
# ╥╨ ║║║║║ ▚  NextGen_ifr6 (7 ms) 5 / ∞ / stop.
# ║╥ ╨║║║║ ▚  NextGen_ifr5 (8 ms)
# ║║╥ ║╨║║ ▚  PrevGen_ifr5 (5 ms)
# ║║╨ ╨ ║║ ▚  Done_ifr6 (11 ms) 5 / ∞ / stop.
# ║║╥   ╨║ ▚  PrevGen_ifr6 (4 ms) 5 / ∞ / stop.
# ║╨║╥╥╥╥╨ ▚  Gen_ifr6 (24 ms) 5 / ∞ / stop.
# ║ ╨╨║║║  ▚  Done_ifr7 (10 ms) 5 / ∞ / stop.
# ╨╥  ╨║║  ▚  Gen_ifr7 (18 ms) 5 / ∞ / stop.
#  ║   ╨║  ▚  PrevGen_ifr7 (3 ms) 5 / ∞ / stop.
# ╥║    ╨  ▚  NextGen_ifr7 (7 ms) 5 / ∞ / stop.
# ╨╨╥      ▚  Gen (24 ms)
#   ╨      ▚  SGCheck (788 ms)
# [     Execution complete.      ]                              </pre></div>
#
#
#  === Timing for Same Generation Logica-style ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | Tree7   | 1.0253999930000646 |
# | Tree8   | 1.1346653619998506 |
# | Tree9   | 1.048337869000079  |
# | Tree10  | 1.2038090660000762 |
# | Tree11  | 1.4260789869999826 |
# | Tree12  | 2.5498552100000325 |
# +---------+--------------------+

# %%
timing
# Out:
# {'a': 0.00015937499999996163,
#  'b': 0.0001060420000000839,
#  'c': 9.687500000010729e-05,
#  'G1k': 1.5715949169999988,
#  'G2k': 4.012602374999993,
#  'G3k': 7.555930625000002,
#  'G4k': 17.507719375000008,
#  'G5k': 27.752416333,
#  'Tree7': 4.729736041999985,
#  'Tree8': 0.8861973330000126,
#  'Tree9': 0.9397843750000163,
#  'Tree10': 0.9565629169999852,
#  'Tree11': 1.3457253750000007,
#  'Tree12': 2.0904798330000176}

# %%
for report in reports:
    print(report)
# Out:
#  === Timing for Test Problem ===
# +---------+------------------------+
# | problem | time                   |
# +---------+------------------------+
# | a       | 0.00022921100003259198 |
# | b       | 0.0001869599999508864  |
# | c       | 0.00017046899995420972 |
# +---------+------------------------+
#  === Timing for Transitive Closure ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | G1k     | 0.8889665329999161 |
# | G2k     | 0.6444625069999574 |
# | G3k     | 0.691283713999951  |
# | G4k     | 0.6476772670000628 |
# | G5k     | 0.6453234560000283 |
# +---------+--------------------+
#  === Timing for Transitive Closure ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | G1k     | 1.8763943879999943 |
# | G2k     | 3.617054680000024  |
# | G3k     | 7.230493697999918  |
# | G4k     | 12.564421521999975 |
# | G5k     | 19.55763669199996  |
# +---------+--------------------+
#  === Timing for Pairwise Distances ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | G1k     | 2.099346245999982  |
# | G2k     | 4.338347781999914  |
# | G3k     | 8.60555926699999   |
# | G4k     | 15.257616865000045 |
# | G5k     | 23.63516611        |
# +---------+--------------------+
#  === Timing for Same Generation ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | Tree7   | 0.7857960700000604 |
# | Tree8   | 0.9151512260000345 |
# | Tree9   | 1.6111061390000714 |
# | Tree10  | 2.1807925879999175 |
# | Tree11  | 7.708316269999955  |
# | Tree12  | 37.75424764900015  |
# +---------+--------------------+
#  === Timing for Same Generation Logica-style ===
# +---------+--------------------+
# | problem | time               |
# +---------+--------------------+
# | Tree7   | 1.0253999930000646 |
# | Tree8   | 1.1346653619998506 |
# | Tree9   | 1.048337869000079  |
# | Tree10  | 1.2038090660000762 |
# | Tree11  | 1.4260789869999826 |
# | Tree12  | 2.5498552100000325 |
# +---------+--------------------+
