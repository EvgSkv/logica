# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgSkv/logica/blob/main/examples/Logica_example_Life_expectency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logica example: Top of countries by life expectancy

# %% [markdown]
# ## Install and import Logica

# %%
# !pip install logica
# Out:
# Collecting logica
#   Downloading https://files.pythonhosted.org/packages/ec/93/c0401a9e48e0a63a99ab7482df637c9f196690ba4be5381bc39388ec0d49/logica-1.2-py3-none-any.whl (568kB)
#      |████████████████████████████████| 573kB 2.5MB/s
# Installing collected packages: logica
# Successfully installed logica-1.2

# %%
from logica import colab_logica
from google.colab import auth
auth.authenticate_user()
colab_logica.SetProject('YOUR_PROJECT_ID')

# %% [markdown]
# ## Countries with highest life expectancy among countries with area above 25k.
#
# We join the life expectancy table with countries area table, filter by country size and order by life expectancy.

# %%
# %%logica TopLife
#
# # Defining short names for public tables.
# LifeExpectancy(..r) :-
#   `bigquery-public-data.census_bureau_international.mortality_life_expectancy`(..r);
# CountryArea(..r) :-
#   `bigquery-public-data.census_bureau_international.country_names_area`(..r);
#
# # Extracting the data.
# @OrderBy(TopLife, "life_expectancy desc");
# @Limit(TopLife, 20);
# TopLife(country_name:, life_expectancy:, country_area:) :-
#   LifeExpectancy(country_name:, life_expectancy:, year: 2016),
#   CountryArea(country_name:, country_area:),
#   country_area > 25000;
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id1"></div>
# Running TopLife
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id2"></div>
# The following query is stored at TopLife_sql variable.
# SELECT
#   bigquerypublicdata_census_bureau_international_mortality_life_expectancy.country_name AS country_name,
#   bigquerypublicdata_census_bureau_international_mortality_life_expectancy.life_expectancy AS life_expectancy,
#   bigquerypublicdata_census_bureau_international_country_names_area.country_area AS country_area
# FROM
#   `bigquery-public-data.census_bureau_international.mortality_life_expectancy` AS bigquerypublicdata_census_bureau_international_mortality_life_expectancy, `bigquery-public-data.census_bureau_international.country_names_area` AS bigquerypublicdata_census_bureau_international_country_names_area
# WHERE
#   (bigquerypublicdata_census_bureau_international_country_names_area.country_area > 25000) AND
#   bigquerypublicdata_census_bureau_international_country_names_area.country_name = bigquerypublicdata_census_bureau_international_mortality_life_expectancy.country_name AND
#   2016 = bigquerypublicdata_census_bureau_international_mortality_life_expectancy.year ORDER BY life_expectancy desc LIMIT 20;
# The following table is stored at TopLife variable.
#       country_name  life_expectancy  country_area
# 0            Japan            85.00      364485.0
# 1          Iceland            83.02      100250.0
# 2      Switzerland            82.57       39997.0
# 3     Korea, South            82.43       96920.0
# 4        Australia            82.23     7682300.0
# 5            Italy            82.20      294140.0
# 6           Sweden            82.06      410335.0
# 7           Canada            81.85     9093507.0
# 8           France            81.84      640427.0
# 9           Norway            81.78      304282.0
# 10           Spain            81.66      498980.0
# 11         Austria            81.48       82445.0
# 12     Netherlands            81.33       33893.0
# 13     New Zealand            81.15      264537.0
# 14         Belgium            80.98       30278.0
# 15         Finland            80.88      303815.0
# 16         Denmark            80.81       42434.0
# 17         Ireland            80.79       68883.0
# 18         Germany            80.68      348672.0
# 19  United Kingdom            80.65      241930.0
